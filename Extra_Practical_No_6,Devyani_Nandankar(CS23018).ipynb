# %% [markdown]
# <a href="https://colab.research.google.com/github/devyani-nandankar/devyani-nandankar.ML-practical.io/blob/main/Extra_Practical_No_6%2CDevyani_Nandankar(CS23018).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Devyani Nandankar(CS23018)

# %% [markdown]
# Aim: To design and implement an Artificial Neural Network for classification problem and evaluate its learning performance.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path= "/content/drive/MyDrive/ML_DATASET/Heart_Failure_Prediction_dataset - Heart_Failure_Prediction_dataset.csv"
df=pd.read_csv(path)
df.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df[df.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
X=df.drop(columns=['HeartDisease'])
y=df['HeartDisease']

# %%
X.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope
# 0              N      0.0       Up
# 1              N      1.0     Flat
# 2              N      0.0       Up
# 3              Y      1.5     Flat
# 4              N      0.0       Up

# %%
#X=pd.get_dummies(X)

# %%
X
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 0      172              N      0.0       Up
# ...

# %%
X.shape
# Out:
# (918, 11)

# %%
X.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope'],
#       dtype='object')

# %%
X=pd.get_dummies(X,dtype=int)

# %%
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_F  Sex_M  \
# 0     40        140          289          0    172      0.0      0      1
# 1     49        160          180          0    156      1.0      1      0
# 2     37        130          283          0     98      0.0      0      1
# 3     48        138          214          0    108      1.5      1      0
# 4     54        150          195          0    122      0.0      0      1
# ..   ...        ...          ...        ...    ...      ...    ...    ...
# 913   45        110          264          0    132      1.2      0      1
# 914   68        144          193          1    141      3.4      0      1
# 915   57        130          131          0    115      1.2      0      1
# 916   57        130          236          0    174      0.0      1      0
# 917   38        138          175          0    173      0.0      0      1
#
#      ChestPainType_ASY  ChestPainType_ATA  ChestPainType_NAP  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,test_size=0.3,random_state=42)
X_train.shape,X_test.shape
# Out:
# ((642, 20), (276, 20))

# %%
X=df.iloc[:,:3:-1]
X
# Out:
#      HeartDisease ST_Slope  Oldpeak ExerciseAngina  MaxHR RestingECG  \
# 0               0       Up      0.0              N    172     Normal
# 1               1     Flat      1.0              N    156     Normal
# 2               0       Up      0.0              N     98         ST
# 3               1     Flat      1.5              Y    108     Normal
# 4               0       Up      0.0              N    122     Normal
# ..            ...      ...      ...            ...    ...        ...
# 913             1     Flat      1.2              N    132     Normal
# 914             1     Flat      3.4              N    141     Normal
# 915             1     Flat      1.2              Y    115     Normal
# 916             1     Flat      0.0              N    174        LVH
# 917             0       Up      0.0              N    173     Normal
#
#      FastingBS  Cholesterol
# 0            0          289
# 1            0          180
# 2            0          283
# ...

# %%
y=df.iloc[:,-1]
print(y)
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
X=pd.get_dummies(X,dtype=int)

# %%
X
# Out:
#      HeartDisease  Oldpeak  MaxHR  FastingBS  Cholesterol  ST_Slope_Down  \
# 0               0      0.0    172          0          289              0
# 1               1      1.0    156          0          180              0
# 2               0      0.0     98          0          283              0
# 3               1      1.5    108          0          214              0
# 4               0      0.0    122          0          195              0
# ..            ...      ...    ...        ...          ...            ...
# 913             1      1.2    132          0          264              0
# 914             1      3.4    141          1          193              0
# 915             1      1.2    115          0          131              0
# 916             1      0.0    174          0          236              0
# 917             0      0.0    173          0          175              0
#
#      ST_Slope_Flat  ST_Slope_Up  ExerciseAngina_N  ExerciseAngina_Y  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.46471433, -1.77231378,  0.2949892 , ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [ 0.78176703, -1.23486848, -1.90539005, ...,  3.93211628,
#         -1.02524056, -0.86288193],
#        [-0.06370685,  1.45235803, -1.90539005, ..., -0.25431598,
#          0.97538084, -0.86288193],
#        ...,
#        [ 0.6760828 , -0.15997788,  0.47365248, ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [ 0.6760828 ,  1.02240179, -1.90539005, ..., -0.25431598,
#         -1.02524056,  1.15890711],
#        [-1.43760192,  0.91491273,  1.78071537, ..., -0.25431598,
#          0.97538084, -0.86288193]])

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
ann=tf.keras.models.Sequential()

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=6,activation='relu'))

# %%
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
ann.fit(X_train,y_train,batch_size=32,epochs=100)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7039 - loss: 0.6156
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7515 - loss: 0.5944
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8006 - loss: 0.5446
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8503 - loss: 0.4981
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8646 - loss: 0.4725
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8421 - loss: 0.4602
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8419 - loss: 0.4444
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8557 - loss: 0.4106
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8492 - loss: 0.4015
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8797 - loss: 0.3723
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8469 - loss: 0.3956
# Epoch 12/100
# ...

# %%
y_pred=ann.predict(X_test)
y_pred=(y_pred>0.5)
y_pred
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# array([[False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
# ...

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print('Confusion Matrix')
cm=confusion_matrix(y_pred,y_test)
print(confusion_matrix(y_pred,y_test))
# Out:
# Confusion Matrix
# [[ 98  26]
#  [ 14 138]]

# %%
print('Accuracy Score')
print(accuracy_score(y_pred,y_test))
# Out:
# Accuracy Score
# 0.855072463768116

# %%
print('classification Report')
print(classification_report(y_pred,y_test))
# Out:
# classification Report
#               precision    recall  f1-score   support
#
#        False       0.88      0.79      0.83       124
#         True       0.84      0.91      0.87       152
#
#     accuracy                           0.86       276
#    macro avg       0.86      0.85      0.85       276
# weighted avg       0.86      0.86      0.85       276
